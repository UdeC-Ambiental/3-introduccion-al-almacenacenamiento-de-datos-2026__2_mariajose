# %% [markdown]
# # 📘 Reto 1 – Lectura y exploración de datos con Pandas
#
# **Objetivo:** cargar el archivo CSV y realizar una exploración básica de los datos.

# %%
import pandas as pd

# 1. Cargar el archivo CSV
datos = pd.read_csv('../data/4_resultados_agua.csv')

# 2. Visualizar las primeras filas
datos.head()
# Out:
#   Punto   Temp    pH  OD_promedio
# 0     A  22.25  7.15          6.2
# 1     B  24.30  7.20          5.8
# 2     C  19.80  6.85          4.9
# 3     D  23.65  7.05          6.5
# 4     E  25.15  7.25          5.0

# %% [markdown]
# ### 🔍 Análisis
# - Identifica las columnas disponibles.
# - Describe los tipos de datos y posibles valores nulos.

# %%
# Dimensiones del dataset
datos.shape
# Out:
# (5, 4)

# %%
# Nombres de columnas
datos.columns
# Out:
# Index(['Punto', 'Temp', 'pH', 'OD_promedio'], dtype='object')

# %%
# Tipos de datos
datos.dtypes
# Out:
# Punto           object
# Temp           float64
# pH             float64
# OD_promedio    float64
# dtype: object

# %%
# Información general
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Punto        5 non-null      object
#  1   Temp         5 non-null      float64
#  2   pH           5 non-null      float64
#  3   OD_promedio  5 non-null      float64
# dtypes: float64(3), object(1)
# memory usage: 292.0+ bytes

# %%
# Valores nulos por columna
datos.isnull().sum()
# Out:
# Punto          0
# Temp           0
# pH             0
# OD_promedio    0
# dtype: int64

# %%
# Estadísticas descriptivas
datos.describe()
# Out:
#             Temp        pH  OD_promedio
# count   5.000000  5.000000     5.000000
# mean   23.030000  7.100000     5.680000
# std     2.093621  0.158114     0.712039
# min    19.800000  6.850000     4.900000
# 25%    22.250000  7.050000     5.000000
# 50%    23.650000  7.150000     5.800000
# 75%    24.300000  7.200000     6.200000
# max    25.150000  7.250000     6.500000

# %% [markdown]
# ## Conclusión
#
# El archivo `4_resultados_agua.csv` fue cargado correctamente usando `pandas`.
# El conjunto de datos contiene 5 registros y 4 columnas: `Punto`, `Temp`, `pH` y `OD_promedio`.
#
# Se identificó que la columna `Punto` es de tipo texto, mientras que `Temp`, `pH` y `OD_promedio` son variables numéricas.
# Además, no se encontraron valores nulos en el dataset.
#
# La exploración inicial permite conocer la estructura de los datos y deja preparada la base para análisis posteriores.
